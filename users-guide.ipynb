# %%
from music21 import *
c = chord.Chord("C4 E4 G4")
c.isConsonant()
# %load_ext music21.ipython21
c.show()

# %%
b = corpus.parse('bach/bwv66.6')
b.show()

# %%
f = note.Note("F5")
f
# Out:
# <music21.note.Note F>

# %%
f.name
# Out:
# 'F'

# %%
f.octave
# Out:
# 5

# %%
f.pitch
# Out:
# <music21.pitch.Pitch F5>

# %%
f.pitch.frequency
# Out:
# 698.456462866008

# %%
f.pitch.pitchClassString
# Out:
# '5'

# %%
f.show()

# %%
f.show('midi')
# Out:
#                 <div id='midiPlayerDiv4340'></div>
#                 <link rel="stylesheet" href="http://artusi.xyz/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': 'http://artusi.xyz/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv4340');
#                                mp.base64Load('...');
#                         });
#                 </script>

# %%
b.show('midi')
# Out:
#                 <div id='midiPlayerDiv6160'></div>
#                 <link rel="stylesheet" href="http://artusi.xyz/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': 'http://artusi.xyz/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv6160');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>
